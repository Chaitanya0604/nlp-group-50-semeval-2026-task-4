# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya0604/nlp-group-50-semeval-2026-task-4/blob/main/Narrative_Story_Similarity_run_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/narrative-similarity-task/semeval-2026-task-4-baselines.git
# Out:
# Cloning into 'semeval-2026-task-4-baselines'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 28 (delta 12), reused 22 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 7.06 KiB | 7.06 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# %cd semeval-2026-task-4-baselines
# Out:
# /content/semeval-2026-task-4-baselines

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached pandas-2.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# ...
# Using cached pandas-2.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.1 which is incompatible.
# ...

# %%
# !pip install pandas==2.2.2 --force-reinstall
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# ...
#   Attempting uninstall: pytz
# ...

# %%
from google.colab import files

uploaded = files.upload()   # Upload JSONL files from your machine
# Out:
#      <input type="file" id="files-8ae0203c-0ebd-407e-9c70-da01c9ec3771" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ae0203c-0ebd-407e-9c70-da01c9ec3771">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

drive_data_path = "/content/drive/MyDrive/semeval-2026-task-4-baselines/data"

os.makedirs(drive_data_path, exist_ok=True)
print("Data folder created at:", drive_data_path)
print("Exists?", os.path.exists(drive_data_path))
# Out:
# Data folder created at: /content/drive/MyDrive/semeval-2026-task-4-baselines/data
# Exists? True

# %%
import shutil

for filename in uploaded.keys():
    print("Copying:", filename)
    shutil.copy(f"/content/{filename}", drive_data_path)
# Out:
# Copying: dev_track_a.jsonl
# Copying: dev_track_b.jsonl

# %%
# !ls -l /content/drive/MyDrive/semeval-2026-task-4-baselines/data/
# Out:
# total 785
# -rw------- 1 root root 450593 Nov 17 17:24 dev_track_a.jsonl
# -rw------- 1 root root 351750 Nov 17 17:24 dev_track_b.jsonl

# %%
# !python /content/semeval-2026-task-4-baselines/track_a.py
# Out:
# Accuracy: 0.465

# %%
# !python /content/semeval-2026-task-4-baselines/track_b.py
# Out:
# 2025-11-17 18:12:00.481445: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763403120.849434   25183 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763403120.944122   25183 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763403121.672684   25183 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
